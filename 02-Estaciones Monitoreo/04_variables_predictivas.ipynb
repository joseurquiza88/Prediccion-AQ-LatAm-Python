# %% [markdown]
# #### OBJETIVO: Analisis de las variables predictivas a traves de series temporales y otros

# %%
#Library
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
# import scipy.stats
# from sklearn.metrics import mean_squared_error
# from math import sqrt
import os
from os import listdir
from datetime import datetime
import pandas as pd
from matplotlib.dates import DateFormatter
import matplotlib.ticker #as ticker|
import matplotlib.dates as mdates
from sklearn.linear_model import LinearRegression
import seaborn as sns
from pathlib import Path
print("librerias")
# Out:
# librerias

# %%
# Cambiar el directorio donde estan los datos
os.chdir("D:/Josefina/Proyectos/ProyectoChile/")

# %%
# Esto lo hice para hacer solo un plot para mostrar en la tesis la variabildiad de una sola estacion 

estacion = "SP"
path = (
    f"{estacion}/proceed/merge_tot/{estacion}_merge_comp.csv"
)
data = pd.read_csv(path)
# Setear fotmato fecha
data['date'] = pd.to_datetime(
    data['date'],
    format="%Y-%m-%d"
)

# Antes
print(len(pd.unique(data['estacion'])), "estaciones")
print(pd.unique(data['estacion']))

data=data [data['estacion']== "Ibirapuera"]
# Despues
print(len(pd.unique(data['estacion'])), "estaciones")
print(pd.unique(data['estacion']))

data["date"] = pd.to_datetime(data["date"])
# Out:
# 16 estaciones
# ['Carapicuiba' 'Marg.Tiete-Pte Remedios' 'Maua' 'Pico do Jaragua'
#  'Pinheiros' 'Santana' 'Santo Amaro' 'Tabao da Serra' 'Parque D.Pedro II'
#  'Guarulhos-Palco Municipal' 'Osasco' 'Ciudad Universitaria - USP'
#  'Guarulhos - Pimentas' 'Ibirapuera' 'Interlagos' 'Itaim Paulista']
# 1 estaciones
# ['Ibirapuera']

# %%
###########################################################################
# PLOT AOD


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- PM2.5 (eje izquierdo)
ax.plot(
    data["date"],
    data["AOD_055"],
    color="steelblue",
    label="AOD_055"
)

ax.set_ylabel("AOD_055", color="steelblue", fontsize=13)
ax.tick_params(axis="y", labelcolor="steelblue")

# %%
###########################################################################
# PLOT BCSMASS_dia


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- BCSMASS_dia
ax.plot(
    data["date"],
    data["BCSMASS_dia"],
    color="#fb6a4a",
    label="BCSMASS_dia"
)

ax.set_ylabel("BCSMASS_dia", color="#fb6a4a", fontsize=13)
ax.tick_params(axis="y", labelcolor="#fb6a4a")

# %%
###########################################################################
# PLOT SO2SMASS_dia


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- SO2SMASS_dia
ax.plot(
    data["date"],
    data["SO2SMASS_dia"],
    color="#9e9ac8",
    label="SO2SMASS_dia"
)

ax.set_ylabel("SO2SMASS_dia", color="#9e9ac8", fontsize=13)
ax.tick_params(axis="y", labelcolor="#9e9ac8")

# %%
###########################################################################
# PLOT SO4SMASS_dia

# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- SO4SMASS_dia
ax.plot(
    data["date"],
    data["SO4SMASS_dia"],
    color="#dd3497",
    label="SO2SMASS_SO4SMASS_diadia"
)

ax.set_ylabel("SO4SMASS_dia", color="#dd3497", fontsize=13)
ax.tick_params(axis="y", labelcolor="#dd3497")

# %%
###########################################################################
# PLOT SSSMASS_dia


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- SSSMASS_dia
ax.plot(
    data["date"],
    data["SSSMASS_dia"],
    color="#fd8d3c",
    label="SSSMASS_dia"
)

ax.set_ylabel("SSSMASS_dia", color="#fd8d3c", fontsize=13)
ax.tick_params(axis="y", labelcolor="#fd8d3c")

# %%
###########################################################################
# PLOT blh_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- blh_mean
ax.plot(
    data["date"],
    data["blh_mean"],
    color="#41b6c4",
    label="blh_mean"
)

ax.set_ylabel("blh_mean", color="#41b6c4", fontsize=13)
ax.tick_params(axis="y", labelcolor="#41b6c4")

# %%
###########################################################################
# PLOT sp_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- blh_mean
ax.plot(
    data["date"],
    data["sp_mean"],
    color="#bdbdbd",
    label="sp_mean"
)

ax.set_ylabel("sp_mean", color="#bdbdbd", fontsize=13)
ax.tick_params(axis="y", labelcolor="#bdbdbd")

# %%
###########################################################################
# PLOT t2m_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- t2m_mean
ax.plot(
    data["date"],
    data["t2m_mean"],
    color="#c7e9c0",
    label="t2m_mean"
)

ax.set_ylabel("t2m_mean", color="#c7e9c0" ,fontsize=13)
ax.tick_params(axis="y", labelcolor="#c7e9c0")

# %%
###########################################################################
# PLOT tp_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- tp_mean
ax.plot(
    data["date"],
    data["tp_mean"],
    color="#980043",
    label="tp_mean"
)

ax.set_ylabel("tp_mean", color="#980043", fontsize=13)
ax.tick_params(axis="y", labelcolor="#980043")

# %%
###########################################################################
# PLOT u10_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- tp_mean
ax.plot(
    data["date"],
    data["u10_mean"],
    color="#fc4e2a",
    label="u10_mean"
)

ax.set_ylabel("u10_mean", color="#fc4e2a", fontsize=13)
ax.tick_params(axis="y", labelcolor="#fc4e2a")

# %%
###########################################################################
# PLOT d2m_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- blh_mean
ax.plot(
    data["date"],
    data["d2m_mean"],
    color="#a1d99b",
    label="d2m_mean"
)

ax.set_ylabel("d2m_mean", color="#a1d99b", fontsize=13)
ax.tick_params(axis="y", labelcolor="#a1d99b")

# %%
###########################################################################
# PLOT v10_mean


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- v10_mean
ax.plot(
    data["date"],
    data["v10_mean"],
    color="#fed976",
    label="v10_mean"
)

ax.set_ylabel("v10_mean", color="#fed976", fontsize=13)
ax.tick_params(axis="y", labelcolor="#a1d99b")

# %%
###########################################################################
# PLOT NDVI


# Fig
fig, ax = plt.subplots(figsize=(10, 4))

# --- NDVI
ax.plot(
    data["date"],
    data["NDVI"],
    color="#fed976",
    label="NDVI"
)

ax.set_ylabel("NDVI", color="#fed976", fontsize=13)
ax.tick_params(axis="y", labelcolor="#a1d99b")
